# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from self_utils import read_all_data_from_files,read_labels_from_csv

# %%
path='E:\\Wifi_based_HAR\\preprocessing'

# %%
all_labels=read_labels_from_csv(path+'\\merged_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 all_labels=read_labels_from_csv(path+'\\merged_data.csv')
#
# NameError: name 'read_labels_from_csv' is not defined

# %%
amplitude,phase,all_labels=read_all_data_from_files(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 amplitude,phase,all_labels=read_all_data_from_files(path)
#
# File e:\Wifi_based_HAR\self\self_utils.py:67, in read_all_data_from_files(paths, antenna_pairs)
#      62 final_amplitudes, final_phases, final_labels = np.empty((0, antenna_pairs * SUBCARRIES_NUM)), \
#      63                                                np.empty((0, antenna_pairs * SUBCARRIES_NUM)), \
#      64                                                np.empty((0))
#      66 for path in paths:
# ---> 67     amplitudes, phases = read_csi_data_from_csv(os.path.join(path, "data.csv"), antenna_pairs)
#      68     labels = read_labels_from_csv(os.path.join(path, "label.csv"),len(amplitudes))
#      70     # Apply the filter
#
# File e:\Wifi_based_HAR\self\self_utils.py:24, in read_csi_data_from_csv(path_to_csv, antenna_pairs)
# ...

# %%
sns.set_theme(color_codes=True)

plt.figure(0, (11, 5))
sns_plot = sns.countplot(all_labels, color="dodgerblue", label="Compact")

# %%
df=pd.read_csv('E:\\Wifi_based_HAR\\preprocessing\\merged_data.csv',header=None)

# %%
df
# Out:
#               0          1          2          3          4          5    \
# 0       22.022716  23.000000  22.000000  25.000000  22.090722   0.000000
# 1       24.698178  26.076810  25.238859  27.802878  25.000000  25.612497
# 2       21.931712  23.259407  22.360680  24.186773  21.954498  21.095023
# 3       24.839485  24.207437  25.000000  25.806976  25.238859  23.853721
# 4       26.419690  26.925824  26.627054  28.600699  25.612497  27.018512
# ...           ...        ...        ...        ...        ...        ...
# 355855  22.561028  23.769729  22.803509  24.351591  22.472205  22.472205
# 355856  22.561028  23.537205  22.561028  25.317978  22.203603  23.086793
# 355857  12.083046  12.083046  13.000000  13.601471  12.649111  11.401754
# 355858  25.495098  26.000000  24.698178  25.298221  24.041631  23.769729
# 355859  22.360680  23.259407  20.615528  23.409400  21.189620  22.135944
#
#               6          7          8          9    ...       94        95   \
# ...

# %%
print(np.any(np.isnan(df)))  # Check again for NaNs
# Out:
# False

# %%
print(df.dtypes)  # Ensure all columns are numeric
# Out:
# 0      float64
# 1      float64
# 2      float64
# 3      float64
# 4      float64
#         ...
# 99     float64
# 100    float64
# 101    float64
# 102    float64
# 103    float64
# Length: 104, dtype: object

# %%
for col in df.columns:
    unique_types = df[col].apply(type).unique()
    if len(unique_types) > 1:
        print(f"Column: {col}, Unique Types: {unique_types}")

# %%
cols_to_check = [23]  # Replace with actual column names if necessary

for col in cols_to_check:
    mask = df[col].apply(lambda x: not isinstance(x, (int, float)))  # Find non-numeric values
    if mask.any():
        print(f"Column {col} has non-numeric values at rows: {df[mask].index.tolist()}")
        print(df.loc[mask, col])  # Display the problematic values

# %%
print(type(df.at[147456, 23]))
# Out:
# <class 'numpy.float64'>

# %%
print(repr(df.at[147456, 23]))
# Out:
# 18.601075237738275
